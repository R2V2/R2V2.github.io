# %%
import nltk
from nltk.corpus import CHILDESCorpusReader
from collections import defaultdict, Counter

corpus_root = '/Users/hermes/Desktop/coding/corpora/linguistic/super_CHILDES'
prov_root = '/Users/hermes/Desktop/coding/corpora/linguistic/super_CHILDES/providence'
CHILDESbank = CHILDESCorpusReader(corpus_root, '.*xml')
providence = CHILDESCorpusReader(prov_root, '.*xml')

# %%
corpusAges = providence.age(month=True)
for x in corpusAges:
    print(x)
# Out:
# 17
# 17
# 18
# 18
# None
# 19
# 20
# 20
# 21
# 21
# 22
# 22
# 23
# 23
# 24
# 24
# 24
# 25
# 26
# 26
# 27
# 27
# 27
# 28
# 28
# 29
# 29
# 30
# 30
# 31
# 31
# 32
# 32
# 33
# 33
# 33
# 34
# 34
# 35
# 35
# 36
# 36
# 37
# 38
# 38
# 38
# 39
# 39
# 40
# 40
# 41
# 42
# 11
# 12
# 12
# 13
# 13
# 14
# 14
# 15
# 15
# 15
# 16
# 16
# 17
# 18
# 18
# 19
# 19
# 19
# 20
# 20
# 21
# 21
# 22
# 22
# 22
# 23
# 23
# 24
# 24
# 25
# 26
# 26
# 27
# 28
# 28
# 29
# 29
# 29
# 30
# 30
# 31
# 31
# 32
# 32
# 33
# 33
# 34
# 34
# 35
# 35
# 13
# 14
# 14
# 14
# 15
# 15
# 16
# 16
# 17
# 17
# 18
# 18
# 19
# 19
# 20
# 20
# 20
# 21
# 21
# 22
# 22
# 23
# 23
# 24
# 24
# 24
# 25
# 25
# 25
# 25
# 26
# 26
# 26
# 26
# 27
# 27
# 28
# 28
# 28
# 29
# 29
# 29
# 30
# 30
# 30
# 30
# 31
# 31
# 31
# 31
# 32
# 32
# 32
# 32
# 32
# 33
# 33
# 33
# 34
# 34
# 34
# 35
# 35
# 35
# 36
# 36
# 36
# 37
# 37
# 38
# 39
# 40
# 41
# 42
# 44
# 45
# 46
# 46
# 47
# 48
# 12
# 12
# 13
# 13
# 14
# 14
# 15
# 15
# 15
# 16
# 16
# 16
# 17
# 17
# 17
# 17
# 18
# 18
# 18
# 19
# 19
# 19
# 20
# 20
# 20
# 20
# 21
# 21
# 21
# 21
# 21
# 22
# 22
# 22
# 22
# 23
# 23
# 23
# 24
# 24
# 24
# 24
# 24
# 25
# 25
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 corpusAges = providence.age(month=True)
# ----> 2 for x in corpusAges:
#       3     print(x)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/nltk/collections.py:412, in LazyMap.iterate_from(self, index)
#     410 while True:
#     411     try:
# --> 412         yield self._func(self._lists[0][index])
#     413     except IndexError:
#     414         return
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/nltk/corpus/reader/childes.py:261, in CHILDESCorpusReader.age.<locals>.<lambda>(fileid)
#     256 if not self._lazy:
#     257     return [
#     258         self._get_age(fileid, speaker, month)
#     259         for fileid in self.abspaths(fileids)
#     260     ]
# --> 261 get_age = lambda fileid: self._get_age(fileid, speaker, month)
#     262 return LazyMap(get_age, self.abspaths(fileids))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/nltk/corpus/reader/childes.py:265, in CHILDESCorpusReader._get_age(self, fileid, speaker, month)
#     264 def _get_age(self, fileid, speaker, month):
# --> 265     xmldoc = ElementTree.parse(fileid).getroot()
#     266     for pat in xmldoc.findall(f".//{{{NS}}}Participants/{{{NS}}}participant"):
#     267         try:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/xml/etree/ElementTree.py:1203, in parse(source, parser)
#    1194 """Parse XML document into element tree.
#    1195
#    1196 *source* is a filename or file object containing XML data,
#    (...)
#    1200
#    1201 """
#    1202 tree = ElementTree()
# -> 1203 tree.parse(source, parser)
#    1204 return tree
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/xml/etree/ElementTree.py:568, in ElementTree.parse(self, source, parser)
#     562     parser = XMLParser()
#     563     if hasattr(parser, '_parse_whole'):
#     564         # The default XMLParser, when it comes from an accelerator,
#     565         # can define an internal _parse_whole API for efficiency.
#     566         # It can be used to parse the whole source without feeding
#     567         # it with chunks.
# --> 568         self._root = parser._parse_whole(source)
#     569         return self._root
#     570 while data := source.read(65536):
#
# KeyboardInterrupt:

# %%
for corpus in providence.corpus():
    print(corpus.age())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 for corpus in CHILDESbank.corpus():
# ----> 2     print(corpus.age())
#
# AttributeError: 'dict' object has no attribute 'age'

# %%
# all child uttterances
child_corpus_counts = defaultdict(Counter)
for word, tag in providence.tagged_words(speaker='CHI'):
    if word in child_corpus_counts:
            child_corpus_counts[word][tag] +=1
    else:
            child_corpus_counts[word] = Counter({tag:1})

# %%
possibleWords = ["maybe", "can", "have", "hafta", "could", "should", "sure", "or", "must", "probably"]
maybe = [sent for sent in providence.sents(speaker="CHI") if "maybe" in sent]
can = [sent for sent in providence.sents(speaker="CHI") if "can" in sent]
hafta = [sent for sent in providence.sents(speaker="CHI") if "hafta" in sent]
have = [sent for sent in providence.sents(speaker="CHI") if "have" in sent]
could = [sent for sent in providence.sents(speaker="CHI") if "could" in sent]
OR = [sent for sent in providence.sents(speaker="CHI") if "or" in sent]
must = [sent for sent in providence.sents(speaker="CHI") if "must" in sent]
sure = [sent for sent in providence.sents(speaker="CHI") if "sure" in sent]
should = [sent for sent in providence.sents(speaker="CHI") if "should" in sent]
probably = [sent for sent in providence.sents(speaker="CHI") if "probably" in sent]
for x in possibleWords:
    print(x, child_corpus_counts[x], sep='\t')
# Out:
# maybe	Counter({'adv': 363})
# can	Counter({'mod': 1595, 'n': 75, '0mod': 22, 'mod~neg': 3, '0n': 1})
# have	Counter({'v': 1105, '0v': 24, 'aux': 22, '0aux': 9})
# hafta	Counter({'mod~inf': 206, 'mod~prep': 5})
# could	Counter({'mod': 167, '0mod': 1})
# should	Counter({'mod': 64, '0mod': 1})
# sure	Counter({'adj': 65, 'adv': 4})
# or	Counter({'coord': 208, '0coord': 4, 'n': 1})
# must	Counter({'mod': 30})
# probably	Counter({'adv': 11})

# %%
could
# Out:
# [['no', 'yyy', 'could', 'eat', 'eat', 'it', 'yyy', 'mouth'],
#  ['could'],
#  ['you', 'could', 'go', 'into', 'the', 'car', 'seat'],
#  ['we', 'could', 'do', 'that', 'then', 'climb', 'on', 'ladder', 'and', 'this'],
#  ['I', 'could', 'sit', "I'll", 'just', 'sit', 'right', 'here'],
#  ['I', 'could', 'do'],
#  ['the', 'engine', 'that', 'could'],
#  ['here', 'yyy', 'yyy', 'xxx', 'you', 'could', 'stop', 'quick'],
#  ['little', 'engine', 'that', 'could'],
#  ['I', 'could', 'not', 'budge', 'that', 'door'],
#  ['maybe', 'he', 'could', 'help'],
#  ['maybe', 'he', 'could', 'be', 'cold'],
#  ['he', 'could', 'be', 'in', 'the', 'snow'],
#  ['he', 'could', 'load', 'the', 'yyy', 'trucks'],
#  ['he', 'could', 'yyy', 'xxx'],
#  ['where', 'where', 'where', 'xxx', 'could', 'it', 'be'],
#  ['could', 'you', 'couple', 'them', 'together'],
#  ['I',
#   'go',
#   'xxx',
#   'yyy',
#   'want',
#   'this',
#   'yyy',
#   'yyy',
#   'know',
#   'we',
#   'could',
#   'see'],
#  ['where', 'owls', 'could', 'go'],
#  ['maybe', 'a', 'truck', 'could', 'help', 'out'],
#  ['we',
#   'could',
#   'yyy',
#   'wanna',
#   'go',
#   'to',
#   'the',
#   'art',
#   'and',
#   'get',
#   'some'],
#  ['maybe', 'that', 'could', 'be', 'his', 'hat'],
#  ['who', 'could', 'it', 'be'],
#  ['could', 'you', 'it', 'broke'],
#  ['they', 'could', 'eat', 'it', 'with', 'a', 'spoon'],
#  ['everybody',
#   'could',
#   'go',
#   'up',
#   'the',
#   'escalator',
#   'down',
#   'the',
#   'escalator',
#   'and',
#   'into',
#   'the',
#   'escalator',
#   'yyy'],
#  ['oh', 'where', 'oh', 'where', 'could', 'my', 'stone', 'be'],
#  ['oh', 'where', 'could', 'my', 'stone', 'be'],
#  ['you', 'could', 'pick', 'the', 'smelly', 'one'],
#  ['you', 'could', 'pick', 'some'],
#  ['he', 'could', 'swim', 'in', 'water'],
#  ['and', 'we', 'could', 'find', 'some'],
#  ['you', 'could', 'touch', 'some'],
#  ['and', 'I', 'could', 'help', 'you'],
#  ['I', 'could', 'play', 'ball', 'with', 'him'],
#  ['I', 'could', 'put', 'it', 'into', 'the', 'oven'],
#  ['it', 'looks', 'like', 'we', 'could', 'put', 'it', 'on'],
#  ['I', 'could', 'use', 'forks', 'you', 'use', 'knives'],
#  ['I', 'could', 'draw', 'with', 'this'],
#  ['could', 'touch', 'it'],
#  ['maybe', 'I', 'could', 'get', 'a', 'brush'],
#  ['rainbow', 'goblins', 'xxx', 'happily', 'as', 'they', 'could', 'be'],
#  ['and',
#   'then',
#   'they',
#   'set',
#   'off',
#   'for',
#   'a',
#   'man',
#   'they',
#   'could',
#   'help'],
#  ['you', 'could', 'do', 'orange'],
#  ['you', 'could', 'do', 'orange'],
#  ['you', 'could', 'draw', 'orange', 'xxx'],
#  ['so', 'she', 'could', 'match', 'xxx', 'place'],
#  ['I',
#   'could',
#   'put',
#   'my',
#   'all',
#   'my',
#   'animals',
#   'into',
#   'my',
#   'big',
#   'girl',
#   'bed'],
#  ['yeah', 'you', 'could', 'hike', 'all', 'the', 'way', 'into', 'Maine'],
#  ['Daddy',
#   'said',
#   "don't",
#   'chew',
#   'it',
#   'with',
#   'my',
#   'teeth',
#   'so',
#   'I',
#   'could',
#   'lick',
#   'it'],
#  ['Daddy', 'said', 'I', 'could', 'lick', 'it'],
#  ['Toad', 'thought', 'of', 'a', 'story', 'but', 'he', 'could', 'not'],
#  ['they',
#   'looked',
#   'in',
#   'all',
#   'the',
#   'places',
#   'but',
#   'no',
#   'one',
#   'could',
#   'find',
#   'his',
#   'yyy'],
#  ['what', 'could', 'Daisy', 'eat'],
#  ['Amanda', 'said', 'she', 'could', 'put', 'it', 'on', 'her', 'refrigerator'],
#  ['I', 'bet', 'we', 'could', 'go', 'to', 'the'],
#  ['yyy', 'we', 'could', 'get', 'our', 'yyy', 'yyy'],
#  ['I', 'wish', 'we', 'could', 'get', 'a', 't', 'there'],
#  ['I', 'wish', 'they', 'could', 'babysit'],
#  ['I',
#   'wish',
#   'I',
#   'was',
#   'a',
#   'grown',
#   'and',
#   'I',
#   'could',
#   'eat',
#   'pepperoni',
#   'and',
#   'mushrooms',
#   'together'],
#  ['but', 'we', 'could', 'put', 'our', 'coats', 'on'],
#  ['we', 'could', 'kick', 'it'],
#  ['those', 'could', 'be', 'red', 'pattern', 'and', 'black', 'pattern'],
#  ['xxx', 'instead', 'of', 'having', 'that', 'I', 'could', 'fight'],
#  ['and', 'I', 'could', 'put', 'this', 'thing', 'on', 'top', 'of', 'there'],
#  ['so', 'we', 'could', 'get', 'that', 'one'],
#  ['that', 'could', 'fit'],
#  ['but', 'I', "don't", 'know', 'if', 'that', 'could', 'fit'],
#  ['well', 'which', 'one', 'could', 'you', 'have'],
#  ['um', 'but', 'what', 'could', 'we', 'do'],
#  ['we', 'could', 'also', 'attach', 'something', 'to', 'this'],
#  ['xxx', 'it', 'could', 'turn', 'left'],
#  ['yyy', 'you', 'could', 'look', 'at', 'my', 'map'],
#  ['xxx',
#   'I',
#   'gave',
#   'it',
#   'to',
#   'you',
#   'so',
#   'you',
#   'could',
#   'go',
#   'to',
#   'the',
#   'pizza',
#   'place'],
#  ['and', 'you', 'could', 'and', 'you', 'could', 'make', 'your', 'own', 'too'],
#  ['a',
#   'silly',
#   'yyy',
#   'a',
#   'silly',
#   'maybe',
#   'he',
#   'could',
#   'see',
#   'a',
#   'a',
#   'silly',
#   'Daddy',
#   'yyy'],
#  ['you', 'could', 'do', 'it'],
#  ['could', 'be', 'in', 'yyy', 'room'],
#  ['xxx', 'grandma', 'could', 'play'],
#  ['could', 'we', 'look', 'for', 'q', 'over', 'here'],
#  ['we', 'could', 'get', "Arthur's", 'tv', 'Trouble'],
#  ['we', 'could', 'look', 'for', "Arthur's", 'New', 'Puppy'],
#  ['yyy', 'gonna', 'see', 'that', 'could', 'be', 'pushed'],
#  ['yyy', 'yyy', 'Mommy', 'who', 'could', 'be', 'a', 'rabbit'],
#  ['who', 'could', 'hop', 'xxx', 'be', 'a', 'rabbit'],
#  ['xxx',
#   'what',
#   'else',
#   'could',
#   'could',
#   'could',
#   'xxx',
#   'how',
#   "'bout",
#   'about',
#   'this'],
#  ['I', 'found', 'Bobby', 'who', 'could', 'do', 'it'],
#  ['I', 'found', 'Bobby', 'who', 'could', 'do', 'it'],
#  ['Mom', 'why', 'could', 'I', 'giggle'],
#  ['xxx', 'that', 'they', 'could', 'not', 'do', 'it'],
#  ['yyy', 'yyy', 'yyy', 'seems', 'they', 'could', 'could', 'go', 'xxx'],
#  ['I', 'put', 'him', 'in', 'there', 'so', 'he', 'could', 'sleep'],
#  ['yyy', 'and', 'the', 'one', 'you', 'could', 'to', 'press', 'down'],
#  ['xxx', 'maybe', 'we', 'could', 'yyy', 'velcro'],
#  ['what', 'yyy', 'could', 'me', 'and', "sleepy's", 'sleepy', 'go', 'to'],
#  ['what', 'could', 'the', 'duckling', 'have', 'swallowed'],
#  ['yyy', 'what', 'could', 'duckling', 'have', 'swallowed'],
#  ['what',
#   'else',
#   'could',
#   'we',
#   'use',
#   'as',
#   'as',
#   'pretend',
#   'money',
#   'other',
#   'than',
#   'this',
#   'one'],
#  ['what', 'could', 'the'],
#  ['Mom',
#   'we',
#   'could',
#   'actually',
#   'I',
#   'wanna',
#   'actually',
#   'make',
#   'an',
#   'up',
#   'above',
#   'stairs',
#   'one',
#   "that's",
#   'up',
#   'here'],
#  ['could', 'make', 'a', 'ceiling', 'I', 'mean', 'through', 'xxx'],
#  ['or', 'we', 'could', 'put', 'the', 'base'],
#  ['yeah', 'mm', 'we', 'could', 'use', 'we', 'could', 'use'],
#  ['yeah', 'could', 'put', 'a', 'chair', 'there'],
#  ['what', 'could', 'we', 'slide', 'underneath'],
#  ["it's",
#   "it's",
#   'you',
#   'could',
#   'yyy',
#   'she',
#   'actually',
#   'rides',
#   'along',
#   'the',
#   'woodland'],
#  ['maybe', 'that', 'book', 'could', 'be', 'under', 'this', 'puppy'],
#  ['maybe', 'he', 'could', 'be', 'under', 'xxx'],
#  ['I', 'think', 'we', 'could', 'just', 'yyy', 'xxx', 'water', 'on', 'him'],
#  ['xxx', 'then', 'Veena', 'could', 'do', 'xxx'],
#  ['we',
#   'could',
#   'because',
#   'we',
#   'could',
#   'rub',
#   'it',
#   'yyy',
#   'yyy',
#   'on',
#   'the',
#   "cow's",
#   'back'],
#  ['no',
#   'this',
#   'could',
#   'be',
#   'a',
#   'milk',
#   'in',
#   'this',
#   'and',
#   'like',
#   'this'],
#  ['and', 'then', 'the', 'cat', 'could'],
#  ['Sleepy',
#   "Bear's",
#   'mommy',
#   'used',
#   'to',
#   'carry',
#   'him',
#   'in',
#   'a',
#   'basket',
#   'so',
#   'he',
#   'could',
#   'see',
#   'everything'],
#  ['yyy',
#   'it',
#   'could',
#   'be',
#   'yyy',
#   'he',
#   'falled',
#   'off',
#   'of',
#   'the',
#   'bed'],
#  ['yyy', 'Grandma', 'xxx', 'could', 'eat', 'it'],
#  ['no', 'or', 'we', 'could', 'put', 'it', 'here'],
#  ['or', 'we', 'could', 'do', 'this'],
#  ['you', 'could', 'do', 'it', 'with', 'me', 'you', 'could'],
#  ['how',
#   'in',
#   'the',
#   'puzzle',
#   'thing',
#   'could',
#   'one',
#   'go',
#   'here',
#   'and',
#   'here',
#   'and',
#   'here'],
#  ['you', 'could', 'name', 'the', 'baby'],
#  ['I', "could've", 'could', 'have', 'sat', 'here', 'xxx'],
#  ['yyy',
#   'and',
#   'and',
#   'people',
#   'who',
#   'live',
#   'there',
#   'could',
#   'get',
#   'power',
#   'outages'],
#  ['heat', 'could', 'be', 'off'],
#  ['cause', 'yyy', 'power', 'power', 'could', 'be'],
#  ['xxx', 'yyy', 'yyy', 'yyy', 'people', 'could', 'have', 'power', 'xxx'],
#  ['they', 'could', 'both', 'fit'],
#  ['you', 'could', 'make', 'my', 'arm'],
#  ['xxx', 'you', 'could', 'make', 'my', 'arm'],
#  ['you', 'could', 'make', 'my', 'hand'],
#  ['could', 'it', 'be'],
#  ['so', 'he', 'could', 'sleep', 'with', 'his', 'friend'],
#  ['we', 'could', 'fit'],
#  ['I', 'could', 'write', 'it'],
#  ['we', 'could', 'make', 'a', 'brownie'],
#  ['I', 'could', 'name'],
#  ['could', 'you', 'put', 'this', 'in', 'here'],
#  ['I', 'wish', 'I', 'could', 'get', 'yyy', 'shorts', 'on', 'him'],
#  ['xxx', 'and', 'crocodile', 'he', 'could', 'swim', 'and', 'xxx'],
#  ['it', 'could', 'be', 'a', 'hermit', 'crab'],
#  ['xxx', 'could', 'be', 'one', 'of', 'this', 'xxx'],
#  ['you', 'go', 'play', 'drum', 'I', 'could', 'play', 'guitar'],
#  ['I', 'could', 'do', 'it', 'like', 'this'],
#  ['could', 'I', 'have', 'some'],
#  ['could', 'I', 'pancakes'],
#  ['how', '', 'we', 'could', 'watch', 'tv'],
#  ['and', 'we', 'could', 'watch'],
#  ['I', 'wonder', 'where', 'it', 'could', 'be'],
#  ['could', 'be'],
#  ["I'm", 'thinking', 'she', 'she', 'could', 'help', 'you'],
#  ['and', 'um', 'I', 'could', 'put', 'my', 'shirt', 'on'],
#  ['uh', 'you', 'could', 'use', 'this'],
#  ['now', 'we', 'could', 'play'],
#  ['xxx', 'you', 'could', 'play', 'your', 'guitar'],
#  ['look', 'you', 'could', 'put', 'your', 'finger', 'there'],
#  ['you', 'could', 'have', 'this', 'ball'],
#  ['if', 'you', 'could', 'swing', 'it', 'hit', 'this', 'house'],
#  ['I', 'could', 'do', 'it', 'I', 'could', 'do', 'it'],
#  ['here', 'you', 'could', 'do', 'that'],
#  ['you', 'could', 'hold', 'my', 'ticket']]

# %%
#create sublists
#total = [sent for sent in CHILDESbank.sents(speaker="FAT" or "MOT")]
#child = [sent for sent in CHILDESbank.sents(speaker="CHI")]
hasto = [sent for sent in providence.sents(speaker="CHI") if "has to" in sent]

# %%
hasto
# Out:
# []

# %%
providence.sents()
# Out:
# [['where', 'do', 'you', 'want', 'me', 'to', 'go'], ['anywhere', "you'll", 'feel', 'comfortable', 'um', 'anywhere'], ...]
